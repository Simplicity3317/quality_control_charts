# %%
class qc_charts():
    
    
    def __init__(self,df):
        import pandas as pd
        import numpy as np
        assert isinstance(df,pd.DataFrame),'Data frame must be a pandas dataframe'
        self.df = df        
        self.df['mean'] = self.df.mean(axis = 1)
        self.x_bar_bar = self.df['mean'].mean()
        df['sd'] = np.std(df.iloc[:,0:-1],axis = 1)
        self.df['Range']  = self.df.iloc[:,0:-2].max(axis = 1) - self.df.iloc[:,0:-2].min(axis = 1)
        self.r_bar = self.df.Range.mean()
        self.df['Index'] = np.NaN
        for a in range(self.df.shape[0]):
            d = a
            #Putting index for the data
            self.df['Index'][a] = int(d+1)
        self.df['Index']= self.df.Index.astype('int')
   
    def range_chart(self,n,title = 'Range Chart',x_label = 'Sample Number',y_label = 'Sample Range'):
        import matplotlib.pyplot as plt
        import numpy as np
        import seaborn as sns
        assert isinstance(n,int), 'n must be an Integer value'
        assert n >= 2, 'n value should not be less than 2'
        if n == 2:
            d4 = 3.267
            d3 = 0
        elif n == 3:
            d4 = 2.574
            d3 = 0
        elif n == 4:
            d4 = 2.282
            d3 = 0
        elif n == 5:
            d4 = 2.114
            d3 = 0
        elif n == 6:
            d4 = 2.004
            d3 = 0
        elif n == 7:
            d4 = 1.924
            d3 = 0.076         
        elif n == 8:
            d4 = 1.864
            d3 = 0.136
        elif n == 9:
            d4 = 1.816
            d3 = 0.184
        elif n == 10:
            d4 = 1.777
            d3 = 0.223
        elif n == 11:
            d4 = 1.744
            d3 = 0.256
        elif n == 12:
            d4 = 1.717
            d3 = 0.283
        elif n == 13:
            d4 = 1.693
            d3 = 0.307
        elif n == 14:
            d4 = 1.672
            d3 = 0.328
        elif n == 15:
            d4 = 1.653
            d3 = 0.347
        elif n == 16:
            d4 = 1.637
            d3 = 0.363
        elif n == 17:
            d4 = 1.622
            d3 = 0.378
        elif n == 18:
            d4 = 1.608
            d3 = 0.391
        elif n == 19:
            d4 = 1.597
            d3 = 0.403
        elif n == 20:
            d4 = 1.585
            d3 = 0.415
        elif n == 21:
            d4 = 1.575
            d3 = 0.425
        elif n == 22:
            d4 = 1.566
            d3 = 0.434
        elif n == 23:
            d4 = 1.557
            d3 = 0.443
        elif n == 24:
            d4 = 1.548
            d3 = 0.451
        elif n == 25:
            d4 = 1.541
            d3 = 0.459    
        self.r_ucl = self.r_bar * d4   
        self.r_lcl = self.r_bar * d3
        self.df['R_ucl'] = np.repeat(self.r_ucl,self.df.shape[0])
        self.df['R_lcl'] = np.repeat(self.r_lcl,self.df.shape[0])
        self.df['R_bar'] = np.repeat(self.r_bar,self.df.shape[0])
        plt.figure(figsize = [10,6])
        sns.lineplot(data = self.df, x = 'Index', y = 'Range', marker = 'o')
        sns.lineplot(data = self.df, x = 'Index', y = 'R_ucl',linestyle = 'dashed')
        sns.lineplot(data = self.df, x = 'Index', y = 'R_lcl',linestyle = 'dashed')
        sns.lineplot(data = self.df, x = 'Index', y = 'R_bar',linestyle = 'dashed')
        plt.text(self.df.Index.max() + 1.5,self.r_lcl, 'LCL = ' + str(round(self.r_lcl,2)))
        plt.text(self.df.Index.max() + 1.5,self.r_ucl ,'UCL = ' + str(round(self.r_ucl,2)))
        plt.text(self.df.Index.max() + 1.5,self.r_bar,'CL =' + str(round(self.r_bar,2)))
        plt.title(title,fontsize = 16)
        plt.xlabel(x_label,fontsize = 16)
        plt.ylabel(y_label,fontsize = 16)
        plt.show()
    def mean_chart(self,n,title = 'X-bar Chart',x_label = 'Sample Number',y_label = 'Sample mean'):
        import matplotlib.pyplot as plt
        import numpy as np
        import seaborn as sns
        assert isinstance(n,int), 'n must be an Integer value'
        assert n >= 2, 'Observations should not be less than 2'
        if n == 2:
            A2 = 1.880
        elif n == 3:
            A2 = 1.023
        elif n == 4:
            A2 = 0.729
        elif n == 5:
            A2 = 0.577
        elif n == 6:
            A2 = 0.483
        elif n == 7:   
            A2 = 0.419
        elif n == 8:
            A2 = 0.373
        elif n == 9:
            A2 = 0.337
        elif n == 10:
            A2 = 0.308
        elif n == 11:
            A2 = 0.285
        elif n == 12:
            A2 = 0.266
        elif n == 13:
            A2 = 0.249
        elif n == 14:
            A2 = 0.235
        elif n == 15:
            A2 = 0.223
        elif n == 16:
            A2 = 0.212
        elif n == 17:
            A2 = 0.203
        elif n == 18:
            A2 = 0.194      
        elif n == 19:
            A2 = 0.187
        elif n == 20:
            A2 = 0.180
        elif n == 21:
            A2 = 0.173
        elif n == 22:
            A2 = 0.167
        elif n == 23:
            A2 = 0.162
        elif n == 24:
            A2 = 0.157
        elif n == 25:
            A2 = 0.153    
        self.mean_ucl = self.x_bar_bar + A2 * self.r_bar
        self.mean_lcl = self.x_bar_bar - A2 * self.r_bar
        self.df['mean_ucl'] = np.repeat(self.mean_ucl,self.df.shape[0])
        self.df['mean_lcl'] = np.repeat(self.mean_lcl,self.df.shape[0])
        self.df['mean_cl'] = np.repeat(self.x_bar_bar,self.df.shape[0])
        plt.figure(figsize = [10,6])
        sns.lineplot(data = self.df, x = 'Index', y = 'mean', marker = 'o')
        sns.lineplot(data = self.df, x = 'Index', y = 'mean_ucl',linestyle = 'dashed')
        sns.lineplot(data = self.df, x = 'Index', y = 'mean_lcl',linestyle = 'dashed')
        sns.lineplot(data = self.df, x = 'Index', y = 'mean_cl',linestyle = 'dashed')
        plt.text(self.df.Index.max() + 1.5,self.mean_lcl, 'LCL = ' + str(round(self.mean_lcl,2)))
        plt.text(self.df.Index.max() + 1.5,self.mean_ucl ,'UCL = ' + str(round(self.mean_ucl,2)))
        plt.text(self.df.Index.max() + 1.5,self.x_bar_bar,'CL =' + str(round(self.x_bar_bar,2)))
        plt.title(title,fontsize = 16)
        plt.xlabel(x_label,fontsize = 16)
        plt.ylabel(y_label,fontsize = 16)
        plt.show()
    def s_chart(self,n,title = 'S chart' ,x_label = 'Sample Number',y_label = 'S'):
        import matplotlib.pyplot as plt
        import numpy as np
        import seaborn as sns
        assert isinstance(n,int), 'n must be an Integer value'
        assert n >= 2, 'Observations should not be less than 2'
        self.s_bar = self.df.sd.mean()
        if n == 2:
            b4 = 3.267
            b3 = 0
        elif n == 3:
            b4 = 2.568
            b3 = 0
        elif n == 4:
            b4 = 2.266
            b3 = 0
        elif n == 5:
            b4 = 2.089
            b3 = 0
        elif n == 6:
            b4 = 1.970
            b3 = 0.030
        elif n == 7:
            b4 = 1.882
            b3 = 0.118
        elif n == 8:
            b4 = 1.815
            b3 = 0.185
        elif n == 9:
            b4 = 1.764
            b3 = 0.239
        elif n == 10:
            b4 = 1.716
            b3 = 0.284
        elif n == 11:
            b4 = 1.679
            b3 = 0.321
        elif n == 12:
            b4 = 1.646
            b3 = 0.354
        elif n == 13:
            b4 = 1.618
            b3 = 0.382
        elif n == 14:
            b4 = 1.594
            b3 = 0.406
        elif n == 15:
            b4 = 1.572
            b3 = 0.428
        elif n == 16:
            b4 = 1.552
            b3 = 0.448
        elif n == 17:
            b4 = 1.534
            b3 = 0.466
        elif n == 18:
            b4 = 1.518
            b3 = 0.482
        elif n == 19:
            b4 = 1.503
            b3 = 0.497
        elif n == 20:
            b4 = 1.490
            b3 = 0.510
        elif n == 21:
            b4 = 1.477
            b3 = 0.523
        elif n == 22:
            b4 = 1.466
            b3 = 0.534
        elif n == 23:
            b4 = 1.455
            b3 = 0.545
        elif n == 24:
            b4 = 1.445
            b3 = 0.555
        elif n == 25:
            b4 = 1.435
            b3 = 0.565
    
        self.s_ucl = self.s_bar * b4
        self.s_lcl = self.s_bar * b3
        self.df['s_ucl'] = np.repeat(self.s_ucl,self.df.shape[0])
        self.df['s_lcl'] = np.repeat(self.s_lcl,self.df.shape[0])
        self.df['s_cl'] = np.repeat(self.s_bar,self.df.shape[0])
        plt.figure(figsize = [10,6])
        sns.lineplot(data = self.df, x = 'Index', y = 'sd', marker = 'o')
        sns.lineplot(data = self.df, x = 'Index', y = 's_ucl',linestyle = 'dashed')
        sns.lineplot(data = self.df, x = 'Index', y = 's_lcl',linestyle = 'dashed')
        sns.lineplot(data = self.df, x = 'Index', y = 's_cl',linestyle = 'dashed')
        plt.text(self.df.Index.max() + 1.5,self.s_lcl, 'LCL = ' + str(round(self.s_lcl,2)))
        plt.text(self.df.Index.max() + 1.5,self.s_ucl ,'UCL = ' + str(round(self.s_ucl,2)))
        plt.text(self.df.Index.max() + 1.5,self.s_bar,'CL =' + str(round(self.s_bar,2)))
        plt.title(title,fontsize = 16)
        plt.xlabel(x_label,fontsize = 16)
        plt.ylabel(y_label,fontsize = 16)
        plt.show()
    def describe_table(self):
        return self.df

# %%
import pandas as pd
data = pd.read_csv('range_table.csv')
data
# Out:
#        A     B     C     D     E
# 0   11.3  10.5  12.4  12.2  12.0
# 1    9.6  11.7  13.0  11.4  12.8
# 2   11.4  12.4  11.7  11.4  12.4
# 3   12.0  11.9  13.2  11.9  12.2
# 4   12.4  11.9  11.7  11.6  10.5
# 5   13.8  12.5  13.9  11.9  11.4
# 6   13.3  11.6  13.2  10.7  11.4
# 7   11.1  11.3  13.2  12.8  12.0
# 8   12.5  11.9  13.8  11.6  13.0
# 9   12.1  11.7  12.0  11.7  12.9
# 10  11.7  12.6  12.3  11.2  10.8
# 11  13.8  12.3  12.4  14.1  11.3
# 12  10.6  11.8  13.1  12.8  11.7
# 13  12.0  11.2  12.1  11.7  12.1
# 14  11.5  13.1  13.9  11.9  10.7
# 15  13.4  12.6  12.4  11.9  11.8
# 16  12.1  13.1  14.1  11.4  12.3
# 17  11.5  13.2  12.4  12.6  12.2
# 18  13.8  14.2  13.5  13.2  12.8
# 19  11.5  11.4  13.1  11.6  10.8

# %%
dtf = qc_charts(data)

# %%
#Plotting range chart 
dtf.range_chart(n = 3,title = 'Range chart for the production of Oil ',y_label = 'Range of Sample',
               x_label = 'Sample')

# %%
#Plotting mean chart
dtf.mean_chart(n = 5)

# %%
#Plotting s chart
dtf.s_chart(n = 7)

# %%
#getting summary table
dtf.describe_table()
# Out:
#        A     B     C     D     E   mean        sd  Range  Index   R_ucl  \
# 0   11.3  10.5  12.4  12.2  12.0  11.68  0.696850    1.9      1  5.2767
# 1    9.6  11.7  13.0  11.4  12.8  11.70  1.216553    3.4      2  5.2767
# 2   11.4  12.4  11.7  11.4  12.4  11.86  0.454313    1.0      3  5.2767
# 3   12.0  11.9  13.2  11.9  12.2  12.24  0.492341    1.3      4  5.2767
# 4   12.4  11.9  11.7  11.6  10.5  11.62  0.624179    1.9      5  5.2767
# 5   13.8  12.5  13.9  11.9  11.4  12.70  1.001998    2.5      6  5.2767
# 6   13.3  11.6  13.2  10.7  11.4  12.04  1.032666    2.6      7  5.2767
# 7   11.1  11.3  13.2  12.8  12.0  12.08  0.818291    2.1      8  5.2767
# 8   12.5  11.9  13.8  11.6  13.0  12.56  0.786384    2.2      9  5.2767
# 9   12.1  11.7  12.0  11.7  12.9  12.08  0.440000    1.2     10  5.2767
# 10  11.7  12.6  12.3  11.2  10.8  11.72  0.667533    1.8     11  5.2767
# 11  13.8  12.3  12.4  14.1  11.3  12.78  1.034215    2.8     12  5.2767
# ...
