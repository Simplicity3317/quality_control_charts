# %% [markdown]
# # Step by Step guide on how to plot x-barR Chart
#
# x-barR Chart is a control chart for process average, it is a variable control chart, which means that the type of observation required for it is a **continuous one**
#
# Use x-barR chart if your subgroup size is few i.e <= 8, if it's greater than that then use x-barS
#
# In this section, we'll take you through on how to plot a mean chart.

# %%
#Import required package.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Importing data to be used

# %%
df = pd.read_csv('data.csv')

# %%
#Printing the first five rows of the dataset
df.head()
# Out:
#    sample_number     A     B     C     D     E
# 0              1  11.3  10.5  12.4  12.2  12.0
# 1              2   9.6  11.7  13.0  11.4  12.8
# 2              3  11.4  12.4  11.7  11.4  12.4
# 3              4  12.0  11.9  13.2  11.9  12.2
# 4              5  12.4  11.9  11.7  11.6  10.5

# %%
#Creating the Mean Column, excluding the sample number column.
df['mean'] = df.iloc[:,1::].mean(axis = 1)

# %%
df.head()
# Out:
#    sample_number     A     B     C     D     E   mean
# 0              1  11.3  10.5  12.4  12.2  12.0  11.68
# 1              2   9.6  11.7  13.0  11.4  12.8  11.70
# 2              3  11.4  12.4  11.7  11.4  12.4  11.86
# 3              4  12.0  11.9  13.2  11.9  12.2  12.24
# 4              5  12.4  11.9  11.7  11.6  10.5  11.62

# %% [markdown]
# ### Next, we need to find the Range of each Sample number, i.e Difference between the Maximum observations and the minimum observations in each Sample.

# %%
#Creating the Mean Column, excluding the sample number column.
df['range'] = df.iloc[:,1:-1:].max(axis = 1) - df.iloc[:,1:-1:].min(axis = 1)

# %%
df.head()
# Out:
#    sample_number     A     B     C     D     E   mean  range
# 0              1  11.3  10.5  12.4  12.2  12.0  11.68    1.9
# 1              2   9.6  11.7  13.0  11.4  12.8  11.70    3.4
# 2              3  11.4  12.4  11.7  11.4  12.4  11.86    1.0
# 3              4  12.0  11.9  13.2  11.9  12.2  12.24    1.3
# 4              5  12.4  11.9  11.7  11.6  10.5  11.62    1.9

# %% [markdown]
# ## Next we find the mean of Means.

# %%
x_bar_bar = df['mean'].mean()

# %%
r_bar = df['range'].mean()

# %% [markdown]
# ### The Control Limits of X-barR chart calculated as follows:
# - UCL(upper control limit) = x_bar_bar + A2 * r_bar
# - CL (control limit) = x_bar_bar
# - LCL(lower control limit) =  x_bar_bar + A2 * r_bar
#
# where:
#
#     x_bar_bar = The mean of Means.
#
#     r_bar = The mean of Range
#
# Our A2 value depends on the **number of observations per Sample number(m)** , in this case my **m = 5**, so we're to check for A2 when **m = 5** , the quality control table to check for A2 value can be found <a href='https://www.mymathtables.com/statistic/xbar-rchart-table.html'>here</a>
#
# Alternatively, let's we can also webscrape it here:

# %%
#using requests to connect to the webpage
req = requests.get('https://www.mymathtables.com/statistic/xbar-rchart-table.html')

# %%
soup = BeautifulSoup(req.text,'lxml')

# %%
#Webscraping the table
table = pd.read_html(str(soup.find('table')),flavor = 'lxml')[0]

# %%
table
# Out:
#     Sample(Size = m)                     A2                     A3  \
# 0                2.0                  1.880                  2.659
# 1                3.0                  1.023                  1.954
# 2                4.0                  0.729                  1.628
# 3                5.0                  0.577                  1.427
# 4                6.0                  0.483                  1.287
# 5                7.0                  0.419                  1.182
# 6                8.0                  0.373                  1.099
# 7                9.0                  0.337                  1.032
# 8               10.0                  0.308                  0.975
# 9               11.0                  0.285                  0.927
# 10              12.0                  0.266                  0.886
# 11              13.0                  0.249                  0.850
# 12              14.0                  0.235                  0.817
# 13              15.0                  0.223                  0.789
# 14              16.0                  0.212                  0.763
# 15              17.0                  0.203                  0.739
# 16              18.0                  0.194                  0.718
# 17              19.0                  0.187                  0.698
# 18              20.0                  0.180                  0.680
# 19              21.0                  0.173                  0.663
# 20              22.0                  0.167                  0.647
# 21              23.0                  0.162                  0.633
# 22              24.0                  0.157                  0.619
# 23              25.0                  0.153                  0.606
# 24               NaN  X-bar Chart Constants  X-bar Chart Constants
#
#                     d2                 D3                 D4  \
# 0                1.128                  0              3.267
# 1                1.693                  0              2.574
# 2                2.059                  0              2.282
# 3                2.326                  0              2.114
# 4                2.534                  0              2.004
# 5                2.704              0.076              1.924
# 6                2.847              0.136              1.864
# 7                2.970              0.184              1.816
# 8                3.078              0.223              1.777
# 9                3.173              0.256              1.744
# 10               3.258              0.283              1.717
# 11               3.336              0.307              1.693
# 12               3.407              0.328              1.672
# 13               3.472              0.347              1.653
# 14               3.532              0.363              1.637
# 15               3.588              0.378              1.622
# 16               3.640              0.391              1.608
# 17               3.689              0.403              1.597
# 18               3.735              0.415              1.585
# 19               3.778              0.425              1.575
# 20               3.819              0.434              1.566
# 21               3.858              0.443              1.557
# 22               3.895              0.451              1.548
# 23               3.931              0.459              1.541
# 24  For Sigma Estimate  R Chart Constants  R Chart Constants
#
#                    B3                 B4
# 0                   0              3.267
# 1                   0              2.568
# 2                   0              2.266
# 3                   0              2.089
# 4               0.030              1.970
# 5               0.118              1.882
# 6               0.185              1.815
# 7               0.239              1.761
# 8               0.284              1.716
# 9               0.321              1.679
# 10              0.354              1.646
# 11              0.382              1.618
# 12              0.406              1.594
# 13              0.428              1.572
# 14              0.448              1.552
# 15              0.466              1.534
# 16              0.482              1.518
# 17              0.497              1.503
# 18              0.510              1.490
# 19              0.523              1.477
# 20              0.534              1.466
# 21              0.545              1.455
# 22              0.555              1.445
# 23              0.565              1.435
# 24  S Chart Constants  S Chart Constants

# %% [markdown]
# ### From the table above, we can see that the corresponding value for A2 when m is 5 is 0.577, we can now find UCL and LCL for x_bar chart

# %%
A2 = 0.57
print('A2 value is: ',A2)
UCL = x_bar_bar + A2 * r_bar
print('UCL value is: ',UCL)
LCL = x_bar_bar - A2 * r_bar
print('LCL value is: ',LCL)
CL = x_bar_bar 
print('CL value is: ',CL)
# Out:
# A2 value is:  0.57
# UCL value is:  13.3525
# LCL value is:  11.0155
# CL value is:  12.184

# %% [markdown]
# ### Now, let's plot the Chart:

# %%
plt.figure(figsize = [10,6])
sns.lineplot(data = df, x = 'sample_number', y = 'mean', marker = 'o')
sns.lineplot(data = df, x = 'sample_number', y = UCL,linestyle = 'dashed')
sns.lineplot(data = df, x = 'sample_number', y =  LCL,linestyle = 'dashed')
sns.lineplot(data = df, x = 'sample_number', y = CL,linestyle = 'dashed')
plt.text(df.sample_number.max() + 1.5,LCL, 'LCL = ' + str(round(LCL,2)))
plt.text(df.sample_number.max() + 1.5,UCL,'UCL = ' + str(round(UCL,2)))
plt.text(df.sample_number.max() + 1.5,CL,'CL =' + str(round(CL,2)))
plt.title('Mean Chart',fontsize = 16);
plt.xticks(range(min(df['sample_number']),max(df['sample_number'])+1));
plt.show()

# %% [markdown]
# #### After plotting the Means on the Y axis and the Sample number on the X axis, we noticed that sample number 19 was out of control,so we remove it and plot the graph again

# %%
#Dropping index 18
df = df.drop(18)

# %%
#Resetting the index
df = df.reset_index(drop = True)

# %%
#Numbering the sample number again,so that we can have 1-19
count = 1
for a in range(df.shape[0]):
    df['sample_number'][a] = count
    count+=1
# Out:
# C:\Users\admin\AppData\Local\Temp/ipykernel_7788/452911733.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sample_number'][a] = count

# %%
df
# Out:
#     sample_number     A     B     C     D     E   mean  range
# 0               1  11.3  10.5  12.4  12.2  12.0  11.68    1.9
# 1               2   9.6  11.7  13.0  11.4  12.8  11.70    3.4
# 2               3  11.4  12.4  11.7  11.4  12.4  11.86    1.0
# 3               4  12.0  11.9  13.2  11.9  12.2  12.24    1.3
# 4               5  12.4  11.9  11.7  11.6  10.5  11.62    1.9
# 5               6  13.8  12.5  13.9  11.9  11.4  12.70    2.5
# 6               7  13.3  11.6  13.2  10.7  11.4  12.04    2.6
# 7               8  11.1  11.3  13.2  12.8  12.0  12.08    2.1
# 8               9  12.5  11.9  13.8  11.6  13.0  12.56    2.2
# 9              10  12.1  11.7  12.0  11.7  12.9  12.08    1.2
# 10             11  11.7  12.6  12.3  11.2  10.8  11.72    1.8
# 11             12  13.8  12.3  12.4  14.1  11.3  12.78    2.8
# 12             13  10.6  11.8  13.1  12.8  11.7  12.00    2.5
# 13             14  12.0  11.2  12.1  11.7  12.1  11.82    0.9
# 14             15  11.5  13.1  13.9  11.9  10.7  12.22    3.2
# 15             16  13.4  12.6  12.4  11.9  11.8  12.42    1.6
# 16             17  12.1  13.1  14.1  11.4  12.3  12.60    2.7
# 17             18  11.5  13.2  12.4  12.6  12.2  12.38    1.7
# 18             19  11.5  11.4  13.1  11.6  10.8  11.68    2.3

# %% [markdown]
# ### Now, let's plot the graph

# %%
plt.figure(figsize = [10,6])
sns.lineplot(data = df, x = 'sample_number', y = 'mean', marker = 'o')
sns.lineplot(data = df, x = 'sample_number', y = UCL,linestyle = 'dashed')
sns.lineplot(data = df, x = 'sample_number', y =  LCL,linestyle = 'dashed')
sns.lineplot(data = df, x = 'sample_number', y = CL,linestyle = 'dashed')
plt.text(df.sample_number.max() + 1.5,LCL, 'LCL = ' + str(round(LCL,2)))
plt.text(df.sample_number.max() + 1.5,UCL,'UCL = ' + str(round(UCL,2)))
plt.text(df.sample_number.max() + 1.5,CL,'CL =' + str(round(CL,2)))
plt.title('Mean Chart',fontsize = 16);
plt.xticks(range(min(df['sample_number']),max(df['sample_number'])+1));
plt.show()
